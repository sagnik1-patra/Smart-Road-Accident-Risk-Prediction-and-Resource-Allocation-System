# %%
import os
import json
import yaml
import pickle
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    accuracy_score,
    classification_report,
    confusion_matrix
)

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping


# ============================================================
# Paths
# ============================================================

BASE_DIR = r"C:\Users\NXTWAVE\Downloads\Smart Road Accident Risk Prediction and Resource Allocation System"
CSV_PATH = os.path.join(BASE_DIR, "Transport_2024_Annexure_3.csv")

os.makedirs(BASE_DIR, exist_ok=True)

PREFIX = "ais_"


# ============================================================
# Load Dataset
# ============================================================

df = pd.read_csv(CSV_PATH)

df.columns = (
    df.columns
    .str.strip()
    .str.replace("\n", " ")
    .str.replace("  ", " ")
)

state_col = "State/UT"

target_col = "State / UT - wise Total Number of Persons Killed in Road Accidents during - 2024 - Number"

rank_col = "State / UT - wise Total Number of Persons Killed in Road Accidents during - 2024 - Rank"


# ============================================================
# Data Cleaning
# ============================================================

for col in df.columns:
    if col != state_col:
        df[col] = (
            df[col]
            .astype(str)
            .str.replace(",", "", regex=False)
            .str.replace("%", "", regex=False)
            .str.strip()
        )
        df[col] = pd.to_numeric(df[col], errors="coerce")

df = df.dropna(subset=[target_col])

numeric_cols = df.select_dtypes(include=[np.number]).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())


# ============================================================
# Feature Engineering
# ============================================================

df["Fatality_Growth_2021_2024"] = (
    (
        df[target_col]
        - df["State / UT - wise Total Number of Persons Killed in Road Accidents during - 2021"]
    )
    /
    (
        df["State / UT - wise Total Number of Persons Killed in Road Accidents during - 2021"]
        + 1
    )
) * 100

df["Fatality_Growth_2023_2024"] = (
    (
        df[target_col]
        - df["State / UT - wise Total Number of Persons Killed in Road Accidents during - 2023"]
    )
    /
    (
        df["State / UT - wise Total Number of Persons Killed in Road Accidents during - 2023"]
        + 1
    )
) * 100

df["Road_Safety_Risk_Index"] = (
    df["Share of States / UTs in Total Number of Persons Killed in Road Accidents - 2024"] * 0.30
    + df["Total Number of Persons Killed in Road Accidents Per Lakh Population - 2024"] * 0.25
    + df["Total Number of Persons Killed in Road Accidents per 10,000 Vehicles - 2022"] * 0.20
    + df["Total Number of Persons Killed in Road Accidents per 10,000 Km of Roads - 2022 (P)"] * 0.25
)

df["Risk_Level"] = pd.qcut(
    df["Road_Safety_Risk_Index"],
    q=3,
    labels=["Low", "Medium", "High"]
)

df["Recommended_Ambulances"] = np.ceil(df[target_col] / 500).astype(int)
df["Recommended_Highway_Patrols"] = np.ceil(df["Road_Safety_Risk_Index"] / 100).astype(int)
df["Recommended_Trauma_Centers"] = np.ceil(df[target_col] / 3000).astype(int)


# ============================================================
# AIS Optimization Function
# ============================================================

def ais_optimize_predictions(predictions, actual_values, iterations=50, clone_factor=10):
    predictions = np.array(predictions, dtype=float)
    actual_values = np.array(actual_values, dtype=float)

    best_predictions = predictions.copy()
    best_error = mean_absolute_error(actual_values, best_predictions)

    for _ in range(iterations):
        clones = []

        for _ in range(clone_factor):
            mutation = np.random.normal(0, 0.05, size=predictions.shape)
            clone = best_predictions * (1 + mutation)
            clone = np.maximum(clone, 0)
            clones.append(clone)

        for clone in clones:
            clone_error = mean_absolute_error(actual_values, clone)

            if clone_error < best_error:
                best_error = clone_error
                best_predictions = clone.copy()

    return best_predictions


# ============================================================
# Features and Targets
# ============================================================

drop_cols = [
    state_col,
    target_col,
    rank_col,
    "Risk_Level"
]

X = df.drop(columns=drop_cols, errors="ignore")
y_reg = df[target_col]

label_encoder = LabelEncoder()
y_cls = label_encoder.fit_transform(df["Risk_Level"])


# ============================================================
# Train-Test Split
# ============================================================

X_train, X_test, y_reg_train, y_reg_test, y_cls_train, y_cls_test = train_test_split(
    X,
    y_reg,
    y_cls,
    test_size=0.25,
    random_state=42,
    stratify=y_cls
)


# ============================================================
# Scaling
# ============================================================

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


# ============================================================
# Random Forest Regression
# ============================================================

rf_regressor = RandomForestRegressor(
    n_estimators=300,
    random_state=42
)

rf_regressor.fit(X_train_scaled, y_reg_train)

rf_reg_pred = rf_regressor.predict(X_test_scaled)

ais_rf_reg_pred = ais_optimize_predictions(
    rf_reg_pred,
    y_reg_test.values,
    iterations=80,
    clone_factor=15
)

ais_rf_reg_metrics = {
    "Model": "AIS Optimized Random Forest Regressor",
    "MAE": mean_absolute_error(y_reg_test, ais_rf_reg_pred),
    "RMSE": np.sqrt(mean_squared_error(y_reg_test, ais_rf_reg_pred)),
    "R2_Score": r2_score(y_reg_test, ais_rf_reg_pred)
}


# ============================================================
# Random Forest Classification
# ============================================================

rf_classifier = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    class_weight="balanced"
)

rf_classifier.fit(X_train_scaled, y_cls_train)

rf_cls_pred = rf_classifier.predict(X_test_scaled)

rf_cls_accuracy = accuracy_score(y_cls_test, rf_cls_pred)

cls_report = classification_report(
    y_cls_test,
    rf_cls_pred,
    target_names=label_encoder.classes_,
    output_dict=True,
    zero_division=0
)

cm = confusion_matrix(y_cls_test, rf_cls_pred)


# ============================================================
# ANN Regression Model
# ============================================================

ann_model = Sequential([
    Dense(128, activation="relu", input_shape=(X_train_scaled.shape[1],)),
    Dropout(0.2),
    Dense(64, activation="relu"),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dense(1)
])

ann_model.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=25,
    restore_best_weights=True
)

history = ann_model.fit(
    X_train_scaled,
    y_reg_train,
    validation_split=0.2,
    epochs=300,
    batch_size=8,
    callbacks=[early_stop],
    verbose=1
)

ann_pred = ann_model.predict(X_test_scaled).flatten()

ais_ann_pred = ais_optimize_predictions(
    ann_pred,
    y_reg_test.values,
    iterations=80,
    clone_factor=15
)

ais_ann_metrics = {
    "Model": "AIS Optimized ANN Regressor",
    "MAE": mean_absolute_error(y_reg_test, ais_ann_pred),
    "RMSE": np.sqrt(mean_squared_error(y_reg_test, ais_ann_pred)),
    "R2_Score": r2_score(y_reg_test, ais_ann_pred)
}


# ============================================================
# Save AIS Models
# ============================================================

ann_model.save(os.path.join(BASE_DIR, PREFIX + "road_accident_ann_model.h5"))

with open(os.path.join(BASE_DIR, PREFIX + "road_accident_ml_models.pkl"), "wb") as f:
    pickle.dump({
        "scaler": scaler,
        "label_encoder": label_encoder,
        "rf_regressor": rf_regressor,
        "rf_classifier": rf_classifier,
        "features": list(X.columns),
        "ais_method": "Artificial Immune System optimization applied on regression predictions"
    }, f)


# ============================================================
# Save AIS YAML and JSON
# ============================================================

config = {
    "project_name": "AIS Smart Road Accident Risk Prediction and Resource Allocation System",
    "dataset_path": CSV_PATH,
    "target_column": target_col,
    "classification_target": "Risk_Level",
    "features": list(X.columns),
    "risk_classes": list(label_encoder.classes_),
    "optimization_algorithm": "Artificial Immune System"
}

with open(os.path.join(BASE_DIR, PREFIX + "road_accident_config.yaml"), "w") as f:
    yaml.dump(config, f, sort_keys=False)

metrics_json = {
    "ais_random_forest_regression": {
        "MAE": float(ais_rf_reg_metrics["MAE"]),
        "RMSE": float(ais_rf_reg_metrics["RMSE"]),
        "R2_Score": float(ais_rf_reg_metrics["R2_Score"])
    },
    "ais_ann_regression": {
        "MAE": float(ais_ann_metrics["MAE"]),
        "RMSE": float(ais_ann_metrics["RMSE"]),
        "R2_Score": float(ais_ann_metrics["R2_Score"])
    },
    "random_forest_classification": {
        "Accuracy": float(rf_cls_accuracy),
        "Classification_Report": cls_report,
        "Confusion_Matrix": cm.tolist()
    }
}

with open(os.path.join(BASE_DIR, PREFIX + "road_accident_metrics.json"), "w") as f:
    json.dump(metrics_json, f, indent=4)


# ============================================================
# AIS Result CSV
# ============================================================

result_df = pd.DataFrame({
    "Actual_2024_Fatalities": y_reg_test.values,
    "RF_Predicted_Fatalities": rf_reg_pred.round(0).astype(int),
    "AIS_RF_Predicted_Fatalities": ais_rf_reg_pred.round(0).astype(int),
    "ANN_Predicted_Fatalities": ann_pred.round(0).astype(int),
    "AIS_ANN_Predicted_Fatalities": ais_ann_pred.round(0).astype(int),
    "Actual_Risk_Level": label_encoder.inverse_transform(y_cls_test),
    "Predicted_Risk_Level": label_encoder.inverse_transform(rf_cls_pred)
})

result_csv_path = os.path.join(BASE_DIR, PREFIX + "road_accident_result.csv")
result_df.to_csv(result_csv_path, index=False)


# ============================================================
# AIS Prediction CSV
# ============================================================

full_scaled = scaler.transform(X)

df["Predicted_2025_Fatalities_RF"] = rf_regressor.predict(full_scaled)

df["Predicted_2025_Fatalities_ANN"] = ann_model.predict(full_scaled).flatten()

df["AIS_Predicted_2025_Fatalities_RF"] = ais_optimize_predictions(
    df["Predicted_2025_Fatalities_RF"].values,
    df[target_col].values,
    iterations=80,
    clone_factor=15
).round(0).astype(int)

df["AIS_Predicted_2025_Fatalities_ANN"] = ais_optimize_predictions(
    df["Predicted_2025_Fatalities_ANN"].values,
    df[target_col].values,
    iterations=80,
    clone_factor=15
).round(0).astype(int)

df["Predicted_Risk_Level"] = label_encoder.inverse_transform(
    rf_classifier.predict(full_scaled)
)

prediction_csv_path = os.path.join(BASE_DIR, PREFIX + "road_accident_prediction.csv")
df.to_csv(prediction_csv_path, index=False)


# ============================================================
# AIS Accuracy Graph
# ============================================================

accuracy_graph_path = os.path.join(BASE_DIR, PREFIX + "accuracy_graph.png")

plt.figure(figsize=(7, 5))
plt.bar(["RF Classifier Accuracy"], [rf_cls_accuracy * 100])
plt.ylabel("Accuracy (%)")
plt.title("AIS Road Accident Risk Classification Accuracy")
plt.ylim(0, 100)
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(accuracy_graph_path, dpi=300)
plt.show()


# ============================================================
# AIS Confusion Matrix Heatmap
# ============================================================

heatmap_path = os.path.join(BASE_DIR, PREFIX + "confusion_matrix_heatmap.png")

plt.figure(figsize=(7, 5))
plt.imshow(cm)
plt.title("AIS Confusion Matrix Heatmap")
plt.colorbar()

classes = label_encoder.classes_
plt.xticks(np.arange(len(classes)), classes)
plt.yticks(np.arange(len(classes)), classes)

for i in range(len(classes)):
    for j in range(len(classes)):
        plt.text(j, i, cm[i, j], ha="center", va="center")

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.savefig(heatmap_path, dpi=300)
plt.show()


# ============================================================
# AIS Comparison CSV and Graph
# ============================================================

comparison_df = pd.DataFrame([
    ais_rf_reg_metrics,
    ais_ann_metrics
])

comparison_csv_path = os.path.join(BASE_DIR, PREFIX + "comparison.csv")
comparison_df.to_csv(comparison_csv_path, index=False)

comparison_graph_path = os.path.join(BASE_DIR, PREFIX + "comparison_graph.png")

plt.figure(figsize=(8, 5))
plt.bar(comparison_df["Model"], comparison_df["R2_Score"])
plt.ylabel("R2 Score")
plt.title("AIS Model Comparison Using R2 Score")
plt.xticks(rotation=15)
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(comparison_graph_path, dpi=300)
plt.show()


# ============================================================
# AIS Result Graph
# ============================================================

result_graph_path = os.path.join(BASE_DIR, PREFIX + "result_graph.png")

plt.figure(figsize=(10, 5))
plt.plot(result_df["Actual_2024_Fatalities"].values, marker="o", label="Actual 2024")
plt.plot(result_df["AIS_RF_Predicted_Fatalities"].values, marker="o", label="AIS RF Predicted")
plt.plot(result_df["AIS_ANN_Predicted_Fatalities"].values, marker="o", label="AIS ANN Predicted")
plt.xlabel("Test Samples")
plt.ylabel("Fatalities")
plt.title("AIS Actual vs Predicted Road Accident Fatalities")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(result_graph_path, dpi=300)
plt.show()


# ============================================================
# AIS Prediction Graph
# ============================================================

prediction_graph_path = os.path.join(BASE_DIR, PREFIX + "prediction_graph.png")

plot_df = df.sort_values("AIS_Predicted_2025_Fatalities_RF", ascending=False).head(15)

plt.figure(figsize=(12, 6))
plt.bar(plot_df[state_col], plot_df["AIS_Predicted_2025_Fatalities_RF"])
plt.xlabel("State/UT")
plt.ylabel("AIS Predicted 2025 Fatalities")
plt.title("Top 15 States/UTs by AIS Predicted 2025 Fatalities")
plt.xticks(rotation=75)
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(prediction_graph_path, dpi=300)
plt.show()


# ============================================================
# AIS Resource Allocation Graph
# ============================================================

resource_graph_path = os.path.join(BASE_DIR, PREFIX + "resource_allocation_graph.png")

resource_df = df.sort_values("Recommended_Ambulances", ascending=False).head(15)

plt.figure(figsize=(12, 6))
plt.bar(resource_df[state_col], resource_df["Recommended_Ambulances"])
plt.xlabel("State/UT")
plt.ylabel("Recommended Ambulances")
plt.title("AIS Recommended Ambulance Allocation")
plt.xticks(rotation=75)
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(resource_graph_path, dpi=300)
plt.show()


# ============================================================
# AIS Risk Distribution Graph
# ============================================================

risk_graph_path = os.path.join(BASE_DIR, PREFIX + "risk_distribution_graph.png")

risk_counts = df["Predicted_Risk_Level"].value_counts()

plt.figure(figsize=(7, 5))
plt.bar(risk_counts.index, risk_counts.values)
plt.xlabel("Risk Level")
plt.ylabel("Number of States/UTs")
plt.title("AIS Predicted Road Accident Risk Distribution")
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(risk_graph_path, dpi=300)
plt.show()


# ============================================================
# Final Output
# ============================================================

print("\nAll AIS files saved successfully in:")
print(BASE_DIR)

print("\nSaved AIS Files:")
print("1.", PREFIX + "road_accident_ann_model.h5")
print("2.", PREFIX + "road_accident_ml_models.pkl")
print("3.", PREFIX + "road_accident_config.yaml")
print("4.", PREFIX + "road_accident_metrics.json")
print("5.", PREFIX + "road_accident_result.csv")
print("6.", PREFIX + "road_accident_prediction.csv")
print("7.", PREFIX + "comparison.csv")
print("8.", PREFIX + "accuracy_graph.png")
print("9.", PREFIX + "confusion_matrix_heatmap.png")
print("10.", PREFIX + "comparison_graph.png")
print("11.", PREFIX + "result_graph.png")
print("12.", PREFIX + "prediction_graph.png")
print("13.", PREFIX + "resource_allocation_graph.png")
print("14.", PREFIX + "risk_distribution_graph.png")

print("\nAIS Model Metrics:")
print("AIS RF Regression:", ais_rf_reg_metrics)
print("AIS ANN Regression:", ais_ann_metrics)
print("RF Classification Accuracy:", rf_cls_accuracy)

print("\nSample AIS Prediction Output:")
print(
    df[
        [
            state_col,
            target_col,
            "Road_Safety_Risk_Index",
            "Risk_Level",
            "AIS_Predicted_2025_Fatalities_RF",
            "AIS_Predicted_2025_Fatalities_ANN",
            "Predicted_Risk_Level",
            "Recommended_Ambulances",
            "Recommended_Highway_Patrols",
            "Recommended_Trauma_Centers"
        ]
    ].head()
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 276ms/step - loss: 1587522688.0000 - mae: 14959.8018 - val_loss: 19179732.0000 - val_mae: 2745.2334
# Epoch 2/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1587491456.0000 - mae: 14959.4258 - val_loss: 19178632.0000 - val_mae: 2745.0466
# Epoch 3/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1587467264.0000 - mae: 14959.1045 - val_loss: 19177508.0000 - val_mae: 2744.8596
# Epoch 4/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss:
300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 461410208.0000 - mae: 9351.2246 - val_loss: 9225906.0000 - val_mae: 2636.6777
# Epoch 111/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 374912928.0000 - mae: 8577.9668 - val_loss: 9403567.0000 - val_mae: 2668.4695
# Epoch 112/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 317210272.0000 - mae: 8194.1631 - val_loss: 9601203.0000 - val_mae: 2702.6384
# Epoch 113/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 499440736.0000 - mae: 9563.0078 - val_loss: 9742145.0000 - val_mae: 2727.6877
# Epoch 114/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 442581376.0000 - mae: 9245.1211 - val_loss: 9980771.0000 - val_mae: 2766.1855
# Epoch 115/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 470576416.0000 - mae: 9403.0156 - val_loss: 10173336.0000 - val_mae: 2796.1663
# Epoch 116/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 360094400.0000 - mae: 8499.8467 - val_loss: 10332391.0000 - val_mae: 2820.2957
# Epoch 117/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 401792896.0000 - mae: 9102.6387 - val_loss: 10402553.0000 - val_mae: 2833.5208
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# All AIS files saved successfully in:
# C:\Users\NXTWAVE\Downloads\Smart Road Accident Risk Prediction and Resource Allocation System
#
# Saved AIS Files:
# 1. ais_road_accident_ann_model.h5
# 2. ais_road_accident_ml_models.pkl
# 3. ais_road_accident_config.yaml
# 4. ais_road_accident_metrics.json
# 5. ais_road_accident_result.csv
# 6. ais_road_accident_prediction.csv
# 7. ais_comparison.csv
# 8. ais_accuracy_graph.png
# 9. ais_confusion_matrix_heatmap.png
# 10. ais_comparison_graph.png
# 11. ais_result_graph.png
# 12. ais_prediction_graph.png
# 13. ais_resource_allocation_graph.png
# 14. ais_risk_distribution_graph.png
#
# AIS Model Metrics:
# AIS RF Regression: {'Model': 'AIS Optimized Random Forest Regressor', 'MAE': 122.01195293910037, 'RMSE': np.float64(148.71092942405494), 'R2_Score': 0.9966094275378908}
# AIS ANN Regression: {'Model': 'AIS Optimized ANN Regressor', 'MAE': 263.2233064530991, 'RMSE': np.float64(391.98429827615956), 'R2_Score': 0.9764427497111201}
# RF Classification Accuracy: 1.0
#
# Sample AIS Prediction Output:
#             State/UT  \
# 0     Andhra Pradesh
# 1  Arunachal Pradesh
# 2              Assam
# 3              Bihar
# 4       Chhattisgarh
#
#    State / UT - wise Total Number of Persons Killed in Road Accidents during - 2024 - Number  \
# 0                                               8346
# 1                                                168
# 2                                               3351
# 3                                               9347
# 4                                               6945
#
#    Road_Safety_Risk_Index Risk_Level  AIS_Predicted_2025_Fatalities_RF  \
# 0                 113.605       High                              7913
# 1                  10.480        Low                               266
# 2                  19.140        Low                              3622
# 3                  78.540     Medium                              9363
# 4                 137.095       High                              7628
#
#    AIS_Predicted_2025_Fatalities_ANN Predicted_Risk_Level  \
# 0                               7730                 High
# 1                               1233                  Low
# 2                               2507                  Low
# 3                               1700               Medium
# 4                               7184                 High
#
#    Recommended_Ambulances  Recommended_Highway_Patrols  \
# 0                      17                            2
# 1                       1                            1
# 2                       7                            1
# 3                      19                            1
# 4                      14                            2
#
#    Recommended_Trauma_Centers
# 0                           3
# 1                           1
# 2                           2
# 3                           4
# 4                           3
